# %%
import RNA
sequence = "TAGCACCATCTGAAATCGGTTA"  # miR-29a spacer example
structure, mfe = RNA.fold(sequence)
print(f"结构: {structure}")
print(f"MFE: {mfe}kcal/mol")
# Out:
# 结构: ....(((..........)))..
# MFE: -0.6000000238418579kcal/mol
